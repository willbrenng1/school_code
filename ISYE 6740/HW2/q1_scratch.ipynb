# %%
import numpy as np

# %%
t=np.array([1,0])

# %%
A=np.matrix([[4,0],[0,3]])

# %%
vals,vectors = np.linalg.eig(A)

# %%
vectors.T
# Out:
# matrix([[1., 0.],
#         [0., 1.]])

# %%
vectors * 3 * vectors.T
# Out:
# matrix([[3., 0.],
#         [0., 3.]])

# %%
ds_1 = [4,7,2,8,3]
np.mean(ds_1),np.var(ds_1)
# Out:
# (np.float64(4.8), np.float64(5.36))

# %%
ds_2 = [4,7,56,8,3]
np.mean(ds_2),np.var(ds_2)
# Out:
# (np.float64(15.6), np.float64(411.43999999999994))
