# %% [markdown]
# Q2

# %%
import pandas as pd
import numpy as np
import math
import numpy as np
import matplotlib.pyplot as plt

e = math.e

def factorial(n):
    return math.factorial(n)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import math
#
# ModuleNotFoundError: No module named 'pandas'

# %%
l = 2
mu = 3
p = 0

# %%
first_term = l/(l+mu
                )

# %%
second_term = (0 - (l/(l+mu)))*e**-(l+mu)*1

# %%
1 - (first_term+second_term)
# Out:
# 0.6026951787996342

# %% [markdown]
# Q5

# %%
1 - factorial(50)/(50**2*factorial(48))
# Out:
# 0.020000000000000018

# %%
1/50
# Out:
# 0.02

# %%
1-(50/50*49/50)
# Out:
# 0.020000000000000018

# %% [markdown]
# Q6

# %%
1 - (49/50)**3*(3-1)/2
# Out:
# 0.05880800000000008

# %%
1 - factorial(365)/(365**3*factorial(362))
# Out:
# 0.008204165884781345

# %%
1 - factorial(50)/(50**3*factorial(47))
# Out:
# 0.05920000000000003

# %% [markdown]
# Q7

# %%
4*(380/500)
# Out:
# 3.04

# %%
np.random.seed(0)

# Generate many uniform xs and ys between 0 and 1
x = np.random.uniform(0, 1, 1000)
y = np.random.uniform(0, 1, 1000)

# %%
# Logical indicating whether or not the point "landed" inside the circle
inside_circle = (x - 0.5)**2 + (y - 0.5)**2 < 0.5**2

# %%
# Graph to show the points and whether or not they landed inside the circle
plt.figure(figsize=(6,6))

# Change the colors: green if inside the circle, red if outside
colors = np.where(inside_circle, 'green', 'red')

plt.scatter(x, y, c=colors, alpha=0.6)
circle = plt.Circle((0.5, 0.5), 0.5, color='blue', fill=False)
plt.gca().add_patch(circle)
plt.show()

# Find proportion by dividing number inside circle divided by total number
print(np.sum(inside_circle) / len(inside_circle))

# Alternative is to take the mean of the logical vectors (1 = True, 0 = False)
print(np.mean(inside_circle))

# Approximation of pi is proportion times 4
print(np.mean(inside_circle) * 4)

# Function that runs one simulation of throwing n_points and calculates
# the approximation for pi by taking 4 times the proportion of darts
# that land inside the circle
def get_pi(n_points):
  x = np.random.uniform(0, 1, n_points)
  y = np.random.uniform(0, 1, n_points)

  inside_circle = (x - 0.5)**2 + (y - 0.5)**2 < 0.5**2

  return np.mean(inside_circle) * 4

# See what happens if select 500 points
print(get_pi(500))

# Run the simulation of 500 points 1000 times
pis = [get_pi(500) for _ in range(int(1e4))]

# Look at the distribution of pi approximations
print(np.percentile(pis, [2.5, 50, 97.5]))

# Run the simulation with many, many more points
pis = [get_pi(int(1e4)) for _ in range(int(1e4))]

print(np.percentile(pis, [2.5, 50, 97.5]))
# Out:
# 0.769
# 0.769
# 3.076
# 3.152
# [2.992 3.144 3.28 ]
# [3.1088 3.142  3.1736]

# %% [markdown]
# Q11

# %%
results = []
ints = []

for i in range(0,4):
    if i ==0:
        results.append((16807*12345678)%((2**31)-1))
    else:
        results.append((16807*results[i-1])%((2**31)-1))
        ints.append(16807*results[i-1])

# %%
results
# Out:
# [1335380034, 380636641, 6240874, 1811154262]

# %%
2**31-1
# Out:
# 2147483647

# %%
ints
# Out:
# [22443732231438, 6397360025287, 104890369318]

# %%
results = []
seed = 12345678
a = 16807
m = 2**31 - 1

for i in range(4):  # Generate 4 random numbers
    if i == 0:
        results.append((a * seed) % m)  # First value
    else:
        results.append((a * results[-1]) % m)

# %%
results
# Out:
# [1335380034, 380636641, 6240874, 1811154262]

# %% [markdown]
# Q12

# %%
la = 1/3
u = .128

-(1/la)*math.log(u)
# Out:
# 6.16717504518756

# %%
11/12
# Out:
# 0.9166666666666666
