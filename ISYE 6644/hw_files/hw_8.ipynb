# %%
import math
import numpy as np
sqrt = math.sqrt

# %% [markdown]
# q9

# %%
x0 = 6632
x0**2
# Out:
# 43983424

# %%
x1 = 9834

x1**2
# Out:
# 96707556

# %%
x2 = 7075

x2**2
# Out:
# 50055625

# %%
556/10000
# Out:
# 0.0556

# %% [markdown]
# q10

# %%
x = 7

for i in range(1,501):
    res = (5*x+3)%16
    print(res,i)
    x=res
# Out:
# 6 1
# 1 2
# 8 3
# 11 4
# 10 5
# 5 6
# 12 7
# 15 8
# 14 9
# 9 10
# 0 11
# 3 12
# 2 13
# 13 14
# 4 15
# 7 16
# 6 17
# 1 18
# 8 19
# 11 20
# 10 21
# 5 22
# 12 23
# 15 24
# 14 25
# 9 26
# 0 27
# 3 28
# 2 29
# 13 30
# 4 31
# 7 32
# 6 33
# 1 34
# 8 35
# 11 36
# 10 37
# 5 38
# 12 39
# 15 40
# 14 41
# 9 42
# 0 43
# 3 44
# 2 45
# 13 46
# 4 47
# 7 48
# 6 49
# 1 50
# 8 51
# 11 52
# 10 53
# 5 54
# 12 55
# 15 56
# 14 57
# 9 58
# 0 59
# 3 60
# 2 61
# 13 62
# 4 63
# 7 64
# 6 65
# 1 66
# 8 67
# 11 68
# 10 69
# 5 70
# 12 71
# 15 72
# 14 73
# 9 74
# 0 75
# 3 76
# 2 77
# 13 78
# 4 79
# 7 80
# 6 81
# 1 82
# 8 83
# 11 84
# 10 85
# 5 86
# 12 87
# 15 88
# 14 89
# 9 90
# 0 91
# 3 92
# 2 93
# 13 94
# 4 95
# 7 96
# 6 97
# 1 98
# 8 99
# 11 100
# 10 101
# 5 102
# 12 103
# 15 104
# 14 105
# 9 106
# 0 107
# 3 108
# 2 109
# 13 110
# 4 111
# 7 112
# 6 113
# 1 114
# 8 115
# 11 116
# 10 117
# 5 118
# 12 119
# 15 120
# 14 121
# 9 122
# 0 123
# 3 124
# 2 125
# 13 126
# 4 127
# 7 128
# 6 129
# 1 130
# 8 131
# 11 132
# ...

# %%
500%16
# Out:
# 4

# %% [markdown]
# Q13

# %%
bits = [1,0,1,0,1,0,1]
# Out:
# 16

# %% [markdown]
# q17

# %%
E = 250


obs = [240,255,243,262]

chi_sq = 0
for e in obs:
    chi_sq+=((e-E)**2)/E

chi_sq
# Out:
# 1.2719999999999998

# %% [markdown]
# Q18

# %%
a = ((2*30 -1)/3)
b = ((16*30 -29)/90)
print(a,b)
# Out:
# 19.666666666666668 5.011111111111111

# %%
(12-29.5)/sqrt(5.01)
# Out:
# -7.81842340315348

# %%
a = ((2*100 -1)/2)
b = ((16*100 -29)/90)
print(a,b)
# Out:
# 99.5 17.455555555555556
