# %%
import pandas as pd

# %%
test_df = pd.DataFrame({'name':['will','paige','sean','laura'],'age':[4,5,4,7]})

# %%
train_df = test_df.sample(frac=.8,random_state=8803)

# %%
test_df.drop(train_df.index)
# Out:
#     name  age
# 3  laura    7

# %%
tuple([train_df,test_df])
# Out:
# (    name  age
#  1  paige    5
#  0   will    4
#  2   sean    4,
#      name  age
#  0   will    4
#  1  paige    5
#  2   sean    4
#  3  laura    7)
